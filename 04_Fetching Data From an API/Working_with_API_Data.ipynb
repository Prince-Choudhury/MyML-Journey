# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b447c03b8ef8f15579f402abb92a06a4&language=en-US&page=1')

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path         genre_ids       id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]      278
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]      238
# 2   False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 3   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]      240
# 4   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]      424
# 5   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]      389
# 6   False  /6oaL4DP75yABrd5EbC4H2zq5ghc.jpg   [16, 10751, 14]      129
# 7   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]    19404
# 8   False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  [18, 28, 80, 53]      155
# 9   False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]      497
# 10  False  /8eihUxjQsJ7WvGySkVMC0EwbPAD.jpg      [35, 53, 18]   496243
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]      680
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#         id                     title  \
# 0      278  The Shawshank Redemption
# 1      238             The Godfather
# 2  1184918            The Wild Robot
# 3      240     The Godfather Part II
# 4      424          Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     230.790
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     269.616
# 2  After a shipwreck, an intelligent robot called...   2024-09-12    4950.682
# 3  In the continuing saga of the Corleone crime f...   1974-12-20     142.298
# 4  The true story of how businessman Oskar Schind...   1993-12-15      82.748
#
#    vote_average  vote_count
# 0         8.707       27005
# 1         8.690       20509
# 2         8.600        1495
# 3         8.600       12369
# 4         8.600       15779

# %%
df.shape
# Out:
# (20, 7)

# %%
df = pd.DataFrame()  #empty data frame
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b447c03b8ef8f15579f402abb92a06a4&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cq/z0kfbyfd20s5xnt2z0xnb9b80000gn/T/ipykernel_70568/435408010.py in ?()
#       1 for i in range(1,429):
#       2     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b447c03b8ef8f15579f402abb92a06a4&language=en-US&page={}'.format(i))
#       3     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# ----> 4     df = df.append(temp_df,ignore_index=True)
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# ...

# %%
import requests

# Define the API endpoint
url = 'https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=vote_average.desc&without_genres=99,10755&vote_count.gte=200'

# Define your Bearer Token (make sure to keep it secure)
headers = {
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNDQ3YzAzYjhlZjhmMTU1NzlmNDAyYWJiOTJhMDZhNCIsIm5iZiI6MTcyOTkyODM4OS44NDk4OTYsInN1YiI6IjY3MWM5OTE0NDU0MmUzNzFmZTBhOTk5ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ceiC3zMg78O3BUH6XNS4QoKv7cjZ3oyvZKnCkT9WNQM',
    'accept': 'application/json'
}

# Make the request
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Convert the response to JSON
    data = response.json()
    # Print out the results
    print(data)
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 230.79, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.707, 'vote_count': 27005}, {'adult': False, 'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg', 'genre_ids': [18, 80], 'id': 238, 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning 
# ...

# %%
import pandas as pd

# Assuming 'results' is the key where the movie list is stored
df1 = pd.DataFrame(data['results'])

# Show the first few rows of the DataFrame
print(df1.head())
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]      278
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]      238
# 2  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 3  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]      240
# 4  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]      424
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en            The Wild Robot
# 3                en     The Godfather Part II
# 4                en          Schindler's List
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     230.790
# 1  Spanning the years 1945 to 1955, a chronicle o...     269.616
# ...

# %%
df1.shape
# Out:
# (20, 14)
